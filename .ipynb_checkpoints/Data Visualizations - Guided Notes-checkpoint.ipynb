# %% [markdown]
# Notebook Lecture 1 - Basic Commands

# %%
# Put your imports here.

# %%
# Read the dataframe, now!

# %%
# Write code here to see the first few rows of the data!

# %%
# Find the age of the person in the seventh row of the dataframe.

# %%
# Write code here to get information about each of the fetures.

# %%
# Write code here to see basic info about the dataset.

# %%
# Nice work!! For the next two lectures, you'll work in the app notebook, not this one. You'll come back here for histograms, though!

# %% [markdown]
# Exercise for Notebook Lecture 1:

# %%
# Your exercise for this lecture is to predict what the distribution of glucose might look like using the quartile scores.
# A rough description, like 'Glucose levels are strongly concentrated in the 120-130 range before tapering off to 180' is perfectly okay.

# %%
# Your response:
#

# %% [markdown]
# Notebook Lecture 2 - Histograms and KDEs

# %%
# Use a matplotlib command to display an age histogram in the Jupyter notebook

# %%
# Use a seaborn command to do the same

# %%
# Make an Age KDE plot in Seaborn

# %%
# Layer two KDE plots, one for positive outcomes and the glucose level, and the other for negative outcomes

# %%
# Make the Age hisogram in streamlit

# %%
# Make the layered KDE plots in streamlit

# %%
# Nice work!! For the next two lectures, you'll work in the app notebook, not this one. Come back here for scatterplots and subplots, though!

# %% [markdown]
# Exercise for Notebook Lecture 2:

# %%
# Create a layered KDE plot of the age distribution by Outcome.

# %%
# Your code goes here:

# %% [markdown]
# Notebook Lecture 3 - Scatterplots and Subplots

# %%
# Make a glucose vs. BMI scatterplot in matplotlib. Add a title and labels for the x and y axes.

# %%
# Make the same plot in Seaborn. Notice how you no longer have to specify titles for the axes. Then, add a hue.

# %%
# Use streamlit syntax and re-create the previous graph.

# %%
# Create a 1 by 2 grid of plots.

# %%
# Look at fig.

# %%
# Lood at axes.

# %%
# Put the seaborn scatterplot in the left plot of the glucose level distribution by outcome in the right plot.

# %%
# If you want to, paste the code from the previous cell here and change the last line to it matches streamlit syntax.

# %%
# Create a 2 by 2 grid of plots.

# %%
# Look at fig.

# %%
# Look at axes.

# %%
# Nice work!! For the next lecture, you'll work in the app notebook, not this one. You'll come back here for heatmaps, though!

# %% [markdown]
# Exercise for Notebook Lecture 3:

# %%
# Create a 2 by 4 grid of subplots, then plot any of the plots we've made on the axes at 1,3 (in Python indexing, not actual 1,3).

# %%
# Your code goes here:

# %% [markdown]
# Notebook Lecture 4 - Heatmaps and Correlations

# %%
# Create the correlation heatmap here

# %% [markdown]
# Notebook Lecture 5 - Cleaning Data

# %%
# Print the head of the data

# %%
# Drop the outcome column

# %%
# Replace the 0s with NaNs

# %%
# Create the null value heatmap

# %%
# Drop the columns in the original dataframe with many missing values
# Make the remaining 0s NaNs
# Reattach the dropped columns
# Drop all rows with NaNs

# %%
# Check out the head again if you'd like.

# %%
# Nice work!! You're almost done with the data visualization portion. Your next lecture will be in the app notebook, not this one. See you there!

# %% [markdown]
# Exercise for Notebook Lecture 5:

# %%
# The command to replace the null values in a column with the mean of the column is the following:
# df['column name'] = df['column name'].fillna(mean_value)

# Step 1: Move the columns with lots of zeros in them (like SkinThickness) to a temporary dataframe. Rather than dropping,
# try: df_temp = pd.concat([df['SkinThickness'],df['smth']],axis=1)

# Step 2: df_temp['column name'] = df_temp['column name'].fillna(mean_value) for each of the columns in df_temp

# Step 3: Drop the old columns with the zeros still in them from the main df.
# Try: df.drop(columns=['SkinThickness',smth],inplace=True)

# Step 4: reattach df_temp using pd.concat

# Step 5: Check out the head of your dataframe!
