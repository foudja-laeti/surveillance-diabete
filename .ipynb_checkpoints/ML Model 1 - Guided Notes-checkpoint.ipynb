# %% [markdown]
# Logistic Regression

# %%
# Import numpy and pandas

# %%
# Read the csv and check the head

# %%
# Assign 'X' to all the inputs (meaning, drop the outcome column)
# Make 'y' the outcome column

# %%
# Split into training and testing sets

# %%
# Scale the features

# %%
# Create and fit the model

# %%
# Make predictions on the test set

# %%
# Evaluate the model

# %%
# Make a specific prediction with the model - remember to transform the data first!

# %% [markdown]
# Exercises - Don't worry about this until after the metrics lecture!

# %%
# Link to spreadsheet, for exercise 1 + reference on how to read an confusion matrix or classification report: (copy paste into your browser, it will prompt you to make a copy)
# https://docs.google.com/spreadsheets/d/1wmgxw5yLa_UJX5ldrph1-w40pPS4ljj2FV9latxGd9g/copy?usp=sharing

# Exercise 2:
# Get probabilities of the positive class (Diabetic)
# y_prob = model.predict_proba(X_test_scaled)[:, 1] <------- Uncomment once you've filled in the code in the logistic regression sectoon

# Apply threshold 0.3 - does this make the model more or less eager to predict 1?
# y_pred = (y_prob >= 0.3).astype(int) <---------- Uncomment

# Evaluate the model - look at precision and recall

# %%
# Apply threshold of 0.7, using the same syntax as the previous cell

# Evaluate the model - look at precision and recall

# %%
# Delete the text in this comment and replace with why you think the pattern you see is hapenning.

# In a diabetes model, do we want higher precision or higher recall? In other words, do we want to catch as much diabetes as possible,
# even if it means ringing false alarms, or do we want to make sure we don't accidentally misdiagnose a negative as a positive? Explain.
